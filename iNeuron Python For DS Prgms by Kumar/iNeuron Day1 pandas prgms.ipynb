# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
print("Hello world")
# Out:
# Hello world

# %%
df= pd.read_csv('C:/Users/ASUS/Downloads/Player.csv')
df
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1       SC Ganguly  08-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith  08-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %%
df.head()
# Out:
#    Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0          1       SC Ganguly  08-Jul-72    Left_Hand    Right-arm medium
# 1          2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2          3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3          4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4          5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
#
#        Country  Is_Umpire  Unnamed: 7
# 0        India          0         NaN
# 1  New Zealand          0         NaN
# 2    Australia          0         NaN
# 3    Australia          0         NaN
# 4     Pakistan          0         NaN

# %%
df.head(20)
# Out:
#     Player_Id      Player_Name        DOB Batting_Hand  \
# 0           1       SC Ganguly  08-Jul-72    Left_Hand
# 1           2      BB McCullum  27-Sep-81   Right_Hand
# 2           3       RT Ponting  19-Dec-74   Right_Hand
# 3           4        DJ Hussey  15-Jul-77   Right_Hand
# 4           5  Mohammad Hafeez  17-Oct-80   Right_Hand
# 5           6         R Dravid  11-Jan-73   Right_Hand
# 6           7         W Jaffer  16-Feb-78   Right_Hand
# 7           8          V Kohli  05-Nov-88   Right_Hand
# 8           9        JH Kallis  16-Oct-75   Right_Hand
# 9          10         CL White  18-Aug-83   Right_Hand
# 10         11       MV Boucher  03-Dec-76   Right_Hand
# 11         12          B Akhil  07-Oct-77   Right_Hand
# 12         13        AA Noffke  30-Apr-77   Right_Hand
# 13         14          P Kumar  02-Oct-86   Right_Hand
# 14         15           Z Khan  07-Oct-78   Right_Hand
# 15         16         SB Joshi  06-Jun-70    Left_Hand
# ...

# %%
df.tail()
# Out:
#      Player_Id   Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 518        519   Subroto Das        NaN          NaN                 NaN
# 519        520  K Srinivasan        NaN          NaN                 NaN
# 520        521     VK Sharma        NaN          NaN                 NaN
# 521        523   AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524   B Aparajith  08-Jul-94   Right_Hand  Right-arm offbreak
#
#     Country  Is_Umpire  Unnamed: 7
# 518   India          1         NaN
# 519   India          1         NaN
# 520   India          1         NaN
# 521   India          0         NaN
# 522   India          0         NaN

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df1=df.head()

# %%
df1
# Out:
#    Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0          1       SC Ganguly  08-Jul-72    Left_Hand    Right-arm medium
# 1          2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2          3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3          4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4          5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
#
#        Country  Is_Umpire  Unnamed: 7
# 0        India          0         NaN
# 1  New Zealand          0         NaN
# 2    Australia          0         NaN
# 3    Australia          0         NaN
# 4     Pakistan          0         NaN

# %%
df1.to_csv("kumar.csv")

# %%
ls
# Out:
#  Volume in drive D is Coding
#  Volume Serial Number is 1008-AFF7
#
#  Directory of D:\jupyter\iNeuron Python For DS Prgms
#
# 08-Jul-24  07:25 PM    <DIR>          .
# 08-Jul-24  07:25 PM    <DIR>          ..
# 08-Jul-24  12:02 PM    <DIR>          .ipynb_checkpoints
# 08-Jul-24  12:04 PM             1,036 iNeuron numpy prgms.ipynb
# 08-Jul-24  06:40 PM            33,251 iNeuron pandas prgms.ipynb
# 08-Jul-24  07:25 PM               424 kumar.csv
#                3 File(s)         34,711 bytes
#                3 Dir(s)  129,788,829,696 bytes free

# %%
pd.read_csv("kumar.csv")# by default it reads comma separator values
# Out:
#    Unnamed: 0  Player_Id      Player_Name        DOB Batting_Hand  \
# 0           0          1       SC Ganguly  08-Jul-72    Left_Hand
# 1           1          2      BB McCullum  27-Sep-81   Right_Hand
# 2           2          3       RT Ponting  19-Dec-74   Right_Hand
# 3           3          4        DJ Hussey  15-Jul-77   Right_Hand
# 4           4          5  Mohammad Hafeez  17-Oct-80   Right_Hand
#
#         Bowling_Skill      Country  Is_Umpire  Unnamed: 7
# 0    Right-arm medium        India          0         NaN
# 1    Right-arm medium  New Zealand          0         NaN
# 2    Right-arm medium    Australia          0         NaN
# 3  Right-arm offbreak    Australia          0         NaN
# 4  Right-arm offbreak     Pakistan          0         NaN

# %%
pd.read_csv("kumar#.csv") # as the default separator is ',' , so it cant read #(hash) separated values
# Out:
#   #Player_Id#Player_Name#DOB#Batting_Hand#Bowling_Skill#Country#Is_Umpire#Unnamed: 7
# 0  0#1#SC Ganguly#08-Jul-72#Left_Hand#Right-arm m...
# 1  1#2#BB McCullum#27-Sep-81#Right_Hand#Right-arm...
# 2  2#3#RT Ponting#19-Dec-74#Right_Hand#Right-arm ...
# 3  3#4#DJ Hussey#15-Jul-77#Right_Hand#Right-arm o...
# 4  4#5#Mohammad Hafeez#17-Oct-80#Right_Hand#Right...

# %%
df2=pd.read_csv("kumar#.csv",sep='#') #so we overwrite the separator to hash

# %%
df2
# Out:
#    Unnamed: 0  Player_Id      Player_Name        DOB Batting_Hand  \
# 0           0          1       SC Ganguly  08-Jul-72    Left_Hand
# 1           1          2      BB McCullum  27-Sep-81   Right_Hand
# 2           2          3       RT Ponting  19-Dec-74   Right_Hand
# 3           3          4        DJ Hussey  15-Jul-77   Right_Hand
# 4           4          5  Mohammad Hafeez  17-Oct-80   Right_Hand
#
#         Bowling_Skill      Country  Is_Umpire  Unnamed: 7
# 0    Right-arm medium        India          0         NaN
# 1    Right-arm medium  New Zealand          0         NaN
# 2    Right-arm medium    Australia          0         NaN
# 3  Right-arm offbreak    Australia          0         NaN
# 4  Right-arm offbreak     Pakistan          0         NaN

# %%
df3=pd.read_csv("kumar#.csv",sep='#',header=None) #by default, it takes 1st line as header, now 1 have overwritten it with none and the header is being removed
df3
# Out:
#      0          1                2          3             4  \
# 0  NaN  Player_Id      Player_Name        DOB  Batting_Hand
# 1  0.0          1       SC Ganguly  08-Jul-72     Left_Hand
# 2  1.0          2      BB McCullum  27-Sep-81    Right_Hand
# 3  2.0          3       RT Ponting  19-Dec-74    Right_Hand
# 4  3.0          4        DJ Hussey  15-Jul-77    Right_Hand
# 5  4.0          5  Mohammad Hafeez  17-Oct-80    Right_Hand
#
#                     5            6          7           8
# 0       Bowling_Skill      Country  Is_Umpire  Unnamed: 7
# 1    Right-arm medium        India          0         NaN
# 2    Right-arm medium  New Zealand          0         NaN
# 3    Right-arm medium    Australia          0         NaN
# 4  Right-arm offbreak    Australia          0         NaN
# 5  Right-arm offbreak     Pakistan          0         NaN

# %%
df4=pd.read_csv('kumar#.csv',sep='#', header=None, names=['a','b','c','d','e','f','g','h']) # I have changed the header names from numbers to chars
df4
# Out:
#              a                b          c             d                   e  \
# NaN  Player_Id      Player_Name        DOB  Batting_Hand       Bowling_Skill
# 0.0          1       SC Ganguly  08-Jul-72     Left_Hand    Right-arm medium
# 1.0          2      BB McCullum  27-Sep-81    Right_Hand    Right-arm medium
# 2.0          3       RT Ponting  19-Dec-74    Right_Hand    Right-arm medium
# 3.0          4        DJ Hussey  15-Jul-77    Right_Hand  Right-arm offbreak
# 4.0          5  Mohammad Hafeez  17-Oct-80    Right_Hand  Right-arm offbreak
#
#                f          g           h
# NaN      Country  Is_Umpire  Unnamed: 7
# 0.0        India          0         NaN
# 1.0  New Zealand          0         NaN
# 2.0    Australia          0         NaN
# 3.0    Australia          0         NaN
# 4.0     Pakistan          0         NaN

# %%
df5=pd.read_csv('kumar#.csv',sep='#', header=None, names=['a','b','c','d','e','f','g','h'], skiprows=[0,1,2])
df5
# Out:
#    a                b          c           d                   e          f  \
# 2  3       RT Ponting  19-Dec-74  Right_Hand    Right-arm medium  Australia
# 3  4        DJ Hussey  15-Jul-77  Right_Hand  Right-arm offbreak  Australia
# 4  5  Mohammad Hafeez  17-Oct-80  Right_Hand  Right-arm offbreak   Pakistan
#
#    g   h
# 2  0 NaN
# 3  0 NaN
# 4  0 NaN

# %%
df
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1       SC Ganguly  08-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith  08-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %%
df6= pd.read_csv('C:/Users/ASUS/Downloads/Player.csv',na_values="SC Ganguly")# na_values means NAN values, this will replace Sc Ganguly as NAN
df6
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1              NaN  08-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith  08-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %%
df
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1       SC Ganguly  08-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith  08-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %%
df.describe() # by default , describe() function alws gives description about only numerical data
# Out:
#         Player_Id   Is_Umpire  Unnamed: 7
# count  523.000000  523.000000   12.000000
# mean   262.003824    0.099426    6.500000
# std    151.127981    0.299520    3.605551
# min      1.000000    0.000000    1.000000
# 25%    131.500000    0.000000    3.750000
# 50%    262.000000    0.000000    6.500000
# 75%    392.500000    0.000000    9.250000
# max    524.000000    1.000000   12.000000

# %%
df.dtypes
# Out:
# Player_Id          int64
# Player_Name       object
# DOB               object
# Batting_Hand      object
# Bowling_Skill     object
# Country           object
# Is_Umpire          int64
# Unnamed: 7       float64
# dtype: object

# %%
df
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1       SC Ganguly  08-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith  08-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %%
df7=df

# %%
df7
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1       SC Ganguly  08-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith  08-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %%
df7.to_csv('resultWithoutIndex.csv',index=False) #it will remove and not store the 1st column which is the unnecessary in our data

# %%
df7.to_csv('resultWithoutHeader.csv',index=False,header=False)

# %%
df7.to_csv('resultWithSpecificColm.csv',columns=['Player_Name', 'Country']) # stores only specific column

# %%
df.tail()
# Out:
#      Player_Id   Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 518        519   Subroto Das        NaN          NaN                 NaN
# 519        520  K Srinivasan        NaN          NaN                 NaN
# 520        521     VK Sharma        NaN          NaN                 NaN
# 521        523   AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524   B Aparajith  08-Jul-94   Right_Hand  Right-arm offbreak
#
#     Country  Is_Umpire  Unnamed: 7
# 518   India          1         NaN
# 519   India          1         NaN
# 520   India          1         NaN
# 521   India          0         NaN
# 522   India          0         NaN

# %%
df.columns
# Out:
# Index(['Player_Id', 'Player_Name', 'DOB', 'Batting_Hand', 'Bowling_Skill',
#        'Country', 'Is_Umpire', 'Unnamed: 7'],
#       dtype='object')

# %%
df['Country']
# Out:
# 0            India
# 1      New Zealand
# 2        Australia
# 3        Australia
# 4         Pakistan
#           ...
# 518          India
# 519          India
# 520          India
# 521          India
# 522          India
# Name: Country, Length: 523, dtype: object

# %%
type(df['Country']) #there are two datatypes in pandas, dataframa and series. series is the one record , it may be a colum or row.Series is the subset of df.
# Out:
# pandas.core.series.Series

# %%
df[['Country']]
# Out:
#          Country
# 0          India
# 1    New Zealand
# 2      Australia
# 3      Australia
# 4       Pakistan
# ..           ...
# 518        India
# 519        India
# 520        India
# 521        India
# 522        India
#
# [523 rows x 1 columns]

# %%
type(df[['Country']]) # if we retrieve the data in the form of list, then it will be considered as df
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Country','Player_Name']] #if we want to retrieve more than 1 column, then compulsory I have to store in the form of list
# Out:
#          Country      Player_Name
# 0          India       SC Ganguly
# 1    New Zealand      BB McCullum
# 2      Australia       RT Ponting
# 3      Australia        DJ Hussey
# 4       Pakistan  Mohammad Hafeez
# ..           ...              ...
# 518        India      Subroto Das
# 519        India     K Srinivasan
# 520        India        VK Sharma
# 521        India      AV Wankhade
# 522        India      B Aparajith
#
# [523 rows x 2 columns]

# %%
pip install openpyxl
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    --------- ------------------------------ 61.4/250.9 kB 1.7 MB/s eta 0:00:01
#    --------------------------- ------------ 174.1/250.9 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  245.8/250.9 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  245.8/250.9 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 250.9/250.9 kB 1.2 MB/s eta 0:00:00
# ...

# %%
df8=pd.read_excel('D:/Kumar Docs/Coding Docs/Sample Datasets/sample-excel-master/LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx')
df8 #it reads only the 1st page in the sheet,ie, Create Profile(see excel file)
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0          NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN
# ...

# %%
df9=pd.read_excel('D:/Kumar Docs/Coding Docs/Sample Datasets/sample-excel-master/LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx',sheet_name='Add your take on balances')
df9
# Out:
#     Unnamed: 0  Unnamed: 1                                         Unnamed: 2  \
# 0          NaN         NaN                                                NaN
# 1          NaN         NaN                                                NaN
# 2          NaN         NaN                                                NaN
# 3          NaN         NaN                                                NaN
# 4          NaN         NaN                                                NaN
# 5          NaN         NaN                                                NaN
# 6          NaN         NaN                                                NaN
# 7          NaN         NaN                                                NaN
# 8          NaN         NaN                                                NaN
# 9          NaN         NaN                                                NaN
# 10         NaN         NaN                                                NaN
# ...

# %%
df10=pd.read_excel('D:/Kumar Docs/Coding Docs/Sample Datasets/sample-excel-master/LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx',sheet_name='Create your test environment')
df10
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3     Unnamed: 4 Unnamed: 5  \
# 0          NaN         NaN         NaN         NaN            NaN        NaN
# 1          NaN         NaN         NaN         NaN            NaN        NaN
# 2          NaN         NaN         NaN         NaN            NaN        NaN
# 3          NaN         NaN         NaN         NaN            NaN        NaN
# 4          NaN         NaN         NaN         NaN            NaN        NaN
# ..         ...         ...         ...         ...            ...        ...
# 75         NaN         NaN         NaN         6.0  LUID_NUU6VTW2          P
# 76         NaN         NaN         NaN         7.0  LUID_JCFXCP3K          P
# 77         NaN         NaN         NaN         8.0  LUID_EGBUB0MA          P
# 78         NaN         NaN         NaN         9.0  LUID_JYQ3JNAD          P
# 79         NaN         NaN         NaN        10.0  LUID_0E6TTHI3          P
#
# ...

# %%
pip install lxml
# Out:
# ...
#
#   Using cached lxml-5.2.2-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Using cached lxml-5.2.2-cp312-cp312-win_amd64.whl (3.8 MB)
# ...

# %%
df11=pd.read_html('https://www.basketball-reference.com/players/i/ibakase01.html')
df11
# Out:
# [       Season   Age   Tm                                       Lg  \
#  0     2008-09  19.0  NaN    Did Not Play (other pro league—Spain)
#  1     2009-10  20.0  OKC                                      NBA
#  2     2010-11  21.0  OKC                                      NBA
#  3     2011-12  22.0  OKC                                      NBA
#  4     2012-13  23.0  OKC                                      NBA
#  5     2013-14  24.0  OKC                                      NBA
#  6     2014-15  25.0  OKC                                      NBA
#  7     2015-16  26.0  OKC                                      NBA
#  8     2016-17  27.0  TOT                                      NBA
#  9     2016-17  27.0  ORL                                      NBA
#  10    2016-17  27.0  TOR                                      NBA
#  11    2017-18  28.0  TOR                                      NBA
#  12    2018-19  29.0  TOR                                      NBA
# ...

# %%
type(df11) #read_html() will read all the tables in the website and store tables in the form of list like table1, table2,....and so on
# Out:
# list

# %%
len(df11)# using len(), we can say that the list has stored 7 tables in it|
# Out:
# 7

# %%
df11[3] # this is the 3rd table in the list
# Out:
#        Season   Age   Tm   Lg  Pos      G     GS       MP      FG     FGA  \
# 0     2009-10  20.0  OKC  NBA   PF   73.0    0.0   1323.0   201.0   370.0
# 1     2010-11  21.0  OKC  NBA   PF   82.0   44.0   2216.0   335.0   617.0
# 2     2011-12  22.0  OKC  NBA   PF   66.0   66.0   1792.0   262.0   490.0
# 3     2012-13  23.0  OKC  NBA   PF   80.0   80.0   2486.0   446.0   778.0
# 4     2013-14  24.0  OKC  NBA   PF   81.0   81.0   2666.0   524.0   978.0
# 5     2014-15  25.0  OKC  NBA   PF   64.0   64.0   2116.0   374.0   786.0
# 6     2015-16  26.0  OKC  NBA   PF   78.0   78.0   2500.0   416.0   869.0
# 7     2016-17  27.0  TOT  NBA   PF   79.0   79.0   2422.0   471.0   982.0
# 8     2016-17  27.0  ORL  NBA   PF   56.0   56.0   1710.0   343.0   703.0
# 9     2016-17  27.0  TOR  NBA   PF   23.0   23.0    712.0   128.0   279.0
# 10    2017-18  28.0  TOR  NBA   PF   76.0   76.0   2093.0   379.0   784.0
# 11    2018-19  29.0  TOR  NBA    C   74.0   51.0   2010.0   464.0   877.0
# ...

# %%
df11[3].to_csv("3rdTableInData.csv") # stored 3rd table from the list into a csv file. this thing cant be done if we write df11.to_csv() bcoz df11 is a list. So 1st I will convert it to a df and then store it .

# %%
pd.read_csv("3rdTableInData.csv")
# Out:
#     Unnamed: 0     Season   Age   Tm   Lg  Pos      G     GS       MP      FG  \
# 0            0    2009-10  20.0  OKC  NBA   PF   73.0    0.0   1323.0   201.0
# 1            1    2010-11  21.0  OKC  NBA   PF   82.0   44.0   2216.0   335.0
# 2            2    2011-12  22.0  OKC  NBA   PF   66.0   66.0   1792.0   262.0
# 3            3    2012-13  23.0  OKC  NBA   PF   80.0   80.0   2486.0   446.0
# 4            4    2013-14  24.0  OKC  NBA   PF   81.0   81.0   2666.0   524.0
# 5            5    2014-15  25.0  OKC  NBA   PF   64.0   64.0   2116.0   374.0
# 6            6    2015-16  26.0  OKC  NBA   PF   78.0   78.0   2500.0   416.0
# 7            7    2016-17  27.0  TOT  NBA   PF   79.0   79.0   2422.0   471.0
# 8            8    2016-17  27.0  ORL  NBA   PF   56.0   56.0   1710.0   343.0
# 9            9    2016-17  27.0  TOR  NBA   PF   23.0   23.0    712.0   128.0
# 10          10    2017-18  28.0  TOR  NBA   PF   76.0   76.0   2093.0   379.0
# ...

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
s= """{
"name" : "Deepak",
"ph_no" : 8787687587656,
"Address" : "Balasore",
"company" : ["Google","Amazon","Microsoft","OnePlus"]
}
"""

# %%
import json

# %%
s1=json.loads(s)
s1
# Out:
# {'name': 'Deepak',
#  'ph_no': 8787687587656,
#  'Address': 'Balasore',
#  'company': ['Google', 'Amazon', 'Microsoft', 'OnePlus']}

# %%
#How to convert a json data to a df?
pd.DataFrame(s1)# converted to json
# Out:
#      name          ph_no   Address    company
# 0  Deepak  8787687587656  Balasore     Google
# 1  Deepak  8787687587656  Balasore     Amazon
# 2  Deepak  8787687587656  Balasore  Microsoft
# 3  Deepak  8787687587656  Balasore    OnePlus

# %%
pd.DataFrame(s1,columns=['company'])# extracted only comapny column from df.
# Out:
#      company
# 0     Google
# 1     Amazon
# 2  Microsoft
# 3    OnePlus

# %%
import requests

# %%
res= requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
res
# Out:
# <Response [200]>

# %%
js=res.json()

# %%
js # as we can see that the dictionaries are stored inside various lists
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59214',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59214/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59214/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59214/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/59214',
#   'id': 2396715927,
#   'node_id': 'PR_kwDOAA0YD850wNW0',
#   'number': 59214,
#   'title': 'Add support for NumpyExtensionArray in pd.unique()',
#   'user': {'login': 'ritwizsinha',
#    'id': 43509699,
#    'node_id': 'MDQ6VXNlcjQzNTA5Njk5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43509699?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ritwizsinha',
#    'html_url': 'https://github.com/ritwizsinha',
# ...

# %%
js[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59214',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59214/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59214/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59214/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/59214',
#  'id': 2396715927,
#  'node_id': 'PR_kwDOAA0YD850wNW0',
#  'number': 59214,
#  'title': 'Add support for NumpyExtensionArray in pd.unique()',
#  'user': {'login': 'ritwizsinha',
#   'id': 43509699,
#   'node_id': 'MDQ6VXNlcjQzNTA5Njk5',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/43509699?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ritwizsinha',
#   'html_url': 'https://github.com/ritwizsinha',
#   'followers_url': 'https://api.github.com/users/ritwizsinha/followers',
# ...

# %%
js[0]['title']
# Out:
# 'Add support for NumpyExtensionArray in pd.unique()'

# %%
js[0]['url']
# Out:
# 'https://api.github.com/repos/pandas-dev/pandas/issues/59214'

# %%
for i in range(len(js)):
    print(js[i]['title']) # fetches all the titles from different lists in this json file
# Out:
# Add support for NumpyExtensionArray in pd.unique()
# BUG: pd.unique() does not accept NumpyExtensionArray
# BUG: regression in master for DataFrame.sparse.from_spmatrix
# BUG: .plot(kind='pie') with ArrowDtype
# CLN: More read_csv state
# ENH: Extend to_numeric to Convert Hexadecimal, Octal, and Binary Strings with Prefixes
# ENH: dt.day_of_week should return int8
# Pyarrow series .any() Error fixed
# BUG: ValueError when accessing dataFrame with array attribute
# ENH: Pipe `attrs` to_html Jinja2 environmental variables
# BUG: Pyarrow series .any() returns a bool, messing up plotting
# DataFrameGroupBy.agg with nan results error Fixed
# DataFrame.eval error fixed
# Difference between calamine and openpyxl readers fixed
# BUG: merge_asof on float does not detect float equality
# BUG: Difference between calamine and openpyxl readers - columns with mixed data types
# ENH: check_dtype='equiv' for assert_frame_equal in unit testing
# DEPR: group by one element list gets scalar keys
# ...

# %%
for i in range(len(js)):
    print(js[i]['node_id'])
# Out:
# PR_kwDOAA0YD850wNW0
# I_kwDOAA0YD86O2RUh
# I_kwDOAA0YD86O1goB
# PR_kwDOAA0YD850uC-h
# PR_kwDOAA0YD850tyzL
# I_kwDOAA0YD86Ov7sh
# PR_kwDOAA0YD850od5m
# PR_kwDOAA0YD850nCWD
# I_kwDOAA0YD86OrhOx
# I_kwDOAA0YD86OorO9
# I_kwDOAA0YD86OoaH2
# PR_kwDOAA0YD850jB57
# PR_kwDOAA0YD850i9yQ
# PR_kwDOAA0YD850i2j4
# I_kwDOAA0YD86OnVuJ
# I_kwDOAA0YD86Ol-Ou
# I_kwDOAA0YD86OgyEn
# PR_kwDOAA0YD850aikg
# PR_kwDOAA0YD850YRtV
# PR_kwDOAA0YD850QXhx
# PR_kwDOAA0YD850QFF0
# I_kwDOAA0YD86ORLTn
# I_kwDOAA0YD86OLF1a
# I_kwDOAA0YD86OKaDJ
# I_kwDOAA0YD86OIbt2
# I_kwDOAA0YD86OISLj
# I_kwDOAA0YD86OIB84
# PR_kwDOAA0YD850F-87
# I_kwDOAA0YD86ODIm1
# PR_kwDOAA0YD85z_7Ea

# %%
df12=pd.DataFrame(js)
df12
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
pd.DataFrame(js,columns=['url','repository_url','labels_url','comments_url','title'])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
df12.head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
# ...

# %%
df12.to_csv("githubApiRequestJson1.csv")

# %%
df13=js[0]['user']
df13
# Out:
# {'login': 'ritwizsinha',
#  'id': 43509699,
#  'node_id': 'MDQ6VXNlcjQzNTA5Njk5',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/43509699?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/ritwizsinha',
#  'html_url': 'https://github.com/ritwizsinha',
#  'followers_url': 'https://api.github.com/users/ritwizsinha/followers',
#  'following_url': 'https://api.github.com/users/ritwizsinha/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/ritwizsinha/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/ritwizsinha/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/ritwizsinha/subscriptions',
#  'organizations_url': 'https://api.github.com/users/ritwizsinha/orgs',
#  'repos_url': 'https://api.github.com/users/ritwizsinha/repos',
#  'events_url': 'https://api.github.com/users/ritwizsinha/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/ritwizsinha/received_events',
# ...

# %%
pd.DataFrame([df13]) #here I have used square bracket becoz to convert a single dictionary to list as pd.DataFrame support list of dictionaries.
# Out:
#          login        id               node_id  \
# 0  ritwizsinha  43509699  MDQ6VXNlcjQzNTA5Njk5
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/435096...
#
#                                         url                        html_url  \
# 0  https://api.github.com/users/ritwizsinha  https://github.com/ritwizsinha
#
#                                        followers_url  \
# 0  https://api.github.com/users/ritwizsinha/follo...
#
#                                        following_url  \
# 0  https://api.github.com/users/ritwizsinha/follo...
#
#                                            gists_url  \
# 0  https://api.github.com/users/ritwizsinha/gists...
#
#                                          starred_url  \
# 0  https://api.github.com/users/ritwizsinha/starr...
#
#                                    subscriptions_url  \
# 0  https://api.github.com/users/ritwizsinha/subsc...
#
# ...

# %%
#task is to collect user data from each list and display the df
for i in range(len(js)):
    print(pd.DataFrame([js[i]['user']])) #this code collects user data individually from each list and prints individually
# Out:
#          login        id               node_id  \
# 0  ritwizsinha  43509699  MDQ6VXNlcjQzNTA5Njk5
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/435096...
#
#                                         url                        html_url  \
# 0  https://api.github.com/users/ritwizsinha  https://github.com/ritwizsinha
#
#                                        followers_url  \
# 0  https://api.github.com/users/ritwizsinha/follo...
#
#                                        following_url  \
# 0  https://api.github.com/users/ritwizsinha/follo...
#
#                                            gists_url  \
# 0  https://api.github.com/users/ritwizsinha/gists...
#
#                                          starred_url  \
# 0  https://api.github.com/users/ritwizsinha/starr...
#
#                                    subscriptions_url  \
# 0  https://api.github.com/users/ritwizsinha/subsc...
#
# ...

# %%
list=[]
for i in range(len(js)):
    list.append((js[i]['user']))
pd.DataFrame(list) #this approach 1st collects all the user data and store it into and empty list and then finally convert that list into df
# Out:
#                    login         id               node_id  \
# 0            ritwizsinha   43509699  MDQ6VXNlcjQzNTA5Njk5
# 1               mutricyl  118692416          U_kgDOBxMaQA
# 2             bmreiniger   40676050  MDQ6VXNlcjQwNjc2MDUw
# 3              mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 4              mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 5                   beci     936184  MDQ6VXNlcjkzNjE4NA==
# 6              rmhowe425   45905457  MDQ6VXNlcjQ1OTA1NDU3
# 7             Riyazul555  121575277          U_kgDOBz8XbQ
# 8                Zybulon   97910143          U_kgDOBdX9fw
# 9          disarticulate   17464125  MDQ6VXNlcjE3NDY0MTI1
# 10              JonPizza   45501389  MDQ6VXNlcjQ1NTAxMzg5
# 11            Riyazul555  121575277          U_kgDOBz8XbQ
# 12            Riyazul555  121575277          U_kgDOBz8XbQ
# 13            Riyazul555  121575277          U_kgDOBz8XbQ
# 14         RaphaelRosset   51163660  MDQ6VXNlcjUxMTYzNjYw
# ...

# %%
df13 = pd.DataFrame([js[i]['user'] for i in range(len(js))]) # same thing done but using list comprehension

# %%
df13
# Out:
#                    login         id               node_id  \
# 0            ritwizsinha   43509699  MDQ6VXNlcjQzNTA5Njk5
# 1               mutricyl  118692416          U_kgDOBxMaQA
# 2             bmreiniger   40676050  MDQ6VXNlcjQwNjc2MDUw
# 3              mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 4              mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 5                   beci     936184  MDQ6VXNlcjkzNjE4NA==
# 6              rmhowe425   45905457  MDQ6VXNlcjQ1OTA1NDU3
# 7             Riyazul555  121575277          U_kgDOBz8XbQ
# 8                Zybulon   97910143          U_kgDOBdX9fw
# 9          disarticulate   17464125  MDQ6VXNlcjE3NDY0MTI1
# 10              JonPizza   45501389  MDQ6VXNlcjQ1NTAxMzg5
# 11            Riyazul555  121575277          U_kgDOBz8XbQ
# 12            Riyazul555  121575277          U_kgDOBz8XbQ
# 13            Riyazul555  121575277          U_kgDOBz8XbQ
# 14         RaphaelRosset   51163660  MDQ6VXNlcjUxMTYzNjYw
# ...

# %%
df14 = pd.DataFrame.from_records(js, columns=['user']) Smae thing 
df14
# Out:
#                                                  user
# 0   {'login': 'ritwizsinha', 'id': 43509699, 'node...
# 1   {'login': 'mutricyl', 'id': 118692416, 'node_i...
# 2   {'login': 'bmreiniger', 'id': 40676050, 'node_...
# 3   {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 4   {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 5   {'login': 'beci', 'id': 936184, 'node_id': 'MD...
# 6   {'login': 'rmhowe425', 'id': 45905457, 'node_i...
# 7   {'login': 'Riyazul555', 'id': 121575277, 'node...
# 8   {'login': 'Zybulon', 'id': 97910143, 'node_id'...
# 9   {'login': 'disarticulate', 'id': 17464125, 'no...
# 10  {'login': 'JonPizza', 'id': 45501389, 'node_id...
# 11  {'login': 'Riyazul555', 'id': 121575277, 'node...
# 12  {'login': 'Riyazul555', 'id': 121575277, 'node...
# 13  {'login': 'Riyazul555', 'id': 121575277, 'node...
# 14  {'login': 'RaphaelRosset', 'id': 51163660, 'no...
# 15  {'login': 'asishm', 'id': 1978117, 'node_id': ...
# ...

# %%
df14=[js[i]['user']  for i in range(len(js))] # Another way of creting list comprehension
pd.DataFrame(df14)
# Out:
#                    login         id               node_id  \
# 0            ritwizsinha   43509699  MDQ6VXNlcjQzNTA5Njk5
# 1               mutricyl  118692416          U_kgDOBxMaQA
# 2             bmreiniger   40676050  MDQ6VXNlcjQwNjc2MDUw
# 3              mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 4              mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 5                   beci     936184  MDQ6VXNlcjkzNjE4NA==
# 6              rmhowe425   45905457  MDQ6VXNlcjQ1OTA1NDU3
# 7             Riyazul555  121575277          U_kgDOBz8XbQ
# 8                Zybulon   97910143          U_kgDOBdX9fw
# 9          disarticulate   17464125  MDQ6VXNlcjE3NDY0MTI1
# 10              JonPizza   45501389  MDQ6VXNlcjQ1NTAxMzg5
# 11            Riyazul555  121575277          U_kgDOBz8XbQ
# 12            Riyazul555  121575277          U_kgDOBz8XbQ
# 13            Riyazul555  121575277          U_kgDOBz8XbQ
# 14         RaphaelRosset   51163660  MDQ6VXNlcjUxMTYzNjYw
# ...
