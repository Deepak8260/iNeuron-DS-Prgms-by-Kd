# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      ------------------------- ------------ 112.6/165.9 kB 6.8 MB/s eta 0:00:01
#      -------------------------------------  163.8/165.9 kB 2.5 MB/s eta 0:00:01
#      -------------------------------------  163.8/165.9 kB 2.5 MB/s eta 0:00:01
#      -------------------------------------  163.8/165.9 kB 2.5 MB/s eta 0:00:01
#      -------------------------------------  163.8/165.9 kB 2.5 MB/s eta 0:00:01
#      -------------------------------------  163.8/165.9 kB 2.5 MB/s eta 0:00:01
#      -------------------------------------  163.8/165.9 kB 2.5 MB/s eta 0:00:01
#      -------------------------------------  163.8/165.9 kB 2.5 MB/s eta 0:00:01
#      -------------------------------------  163.8/165.9 kB 2.5 MB/s eta 0:00:01
#      ------------------------------------ 165.9/165.9 kB 356.2 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
# ...

# %%
# !pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    --------------- ------------------------ 112.6/294.9 kB 6.8 MB/s eta 0:00:01
#    -------------------------- ------------- 194.6/294.9 kB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 276.5/294.9 kB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 1.8 MB/s eta 0:00:01
#    -------------------------------------- 294.9/294.9 kB 961.7 kB/s eta 0:00:00
# ...

# %%
# !pip install scipy
# Out:
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.8 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.8 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.8 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.8 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.8 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.8 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.8 kB ? eta -:--:--
#      -------------------------------------- 60.8/60.8 kB 129.2 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.2/44.5 MB 12.3 MB/s eta 0:00:04
#    ---------------------------------------- 0.3/44.5 MB 2.6 MB/s eta 0:00:17
#    ---------------------------------------- 0.4/44.5 MB 2.6 MB/s eta 0:00:18
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
np.random.seed(20)
df=pd.DataFrame(np.random.rand(1000,1),index=(pd.date_range('13-07-2024',periods=1000)),columns=['Data'])

# %%
df
# Out:
#                 Data
# 2024-07-13  0.588131
# 2024-07-14  0.897714
# 2024-07-15  0.891531
# 2024-07-16  0.815837
# 2024-07-17  0.035890
# ...              ...
# 2027-04-04  0.992189
# 2027-04-05  0.756037
# 2027-04-06  0.299186
# 2027-04-07  0.261712
# 2027-04-08  0.968979
#
# [1000 rows x 1 columns]

# %%
df.plot() #these graphs are constructud using pandas plot().
# Out:
# <Axes: >

# %%
df.Data.cumsum()#cumulative sum
# Out:
# 2024-07-13      0.588131
# 2024-07-14      1.485845
# 2024-07-15      2.377375
# 2024-07-16      3.193213
# 2024-07-17      3.229102
#                  ...
# 2027-04-04    495.812936
# 2027-04-05    496.568973
# 2027-04-06    496.868159
# 2027-04-07    497.129872
# 2027-04-08    498.098851
# Freq: D, Name: Data, Length: 1000, dtype: float64

# %%
df.Data.cumsum().plot()
# Out:
# <Axes: >

# %%
df['data1']=df.Data.cumsum()

# %%
df['data2']=df['Data'].apply(lambda x : x**2)

# %%
df
# Out:
#                 Data       data1     data2
# 2024-07-13  0.588131    0.588131  0.345898
# 2024-07-14  0.897714    1.485845  0.805890
# 2024-07-15  0.891531    2.377375  0.794827
# 2024-07-16  0.815837    3.193213  0.665591
# 2024-07-17  0.035890    3.229102  0.001288
# ...              ...         ...       ...
# 2027-04-04  0.992189  495.812936  0.984438
# 2027-04-05  0.756037  496.568973  0.571592
# 2027-04-06  0.299186  496.868159  0.089513
# 2027-04-07  0.261712  497.129872  0.068493
# 2027-04-08  0.968979  498.098851  0.938920
#
# [1000 rows x 3 columns]

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(figsize=(10,10))
# Out:
# <Axes: >

# %%
df1=sns.load_dataset('iris')

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot(figsize=(10,10))
# Out:
# <Axes: >

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
gf=df1.plot(title='iris Dataset')
gf.set_xlabel("X-axis = Index size")
gf.set_ylabel("Y=axis = Data")
# Out:
# Text(0, 0.5, 'Y=axis = Data')

# %%
df1.iloc[0][0:4].plot()
# Out:
# <Axes: >

# %%
df1.iloc[0][0:4]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %%
df1.iloc[0][0:4].plot(kind='bar')#bar graph for the series
# Out:
# <Axes: >

# %%
df1.iloc[[0],0:4]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2

# %%
df1.iloc[[0],0:4].plot(kind='bar') #bar graph for the df
# Out:
# <Axes: >

# %%
df2=sns.load_dataset('titanic')

# %%
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2['pclass'].plot(kind='bar')
# Out:
# <Axes: >

# %%
df3=pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])

# %%
df3
# Out:
#           a         b         c         d
# 0  0.754462  0.591334  0.108692  0.402853
# 1  0.269676  0.573075  0.916855  0.189785
# 2  0.944349  0.820192  0.229638  0.697904
# 3  0.701251  0.570189  0.448045  0.332812
# 4  0.108018  0.121464  0.420368  0.336497
# 5  0.389588  0.301919  0.312265  0.036205
# 6  0.378922  0.010581  0.357048  0.083158
# 7  0.705395  0.816193  0.262531  0.382466
# 8  0.897100  0.437109  0.842188  0.852225
# 9  0.123356  0.150039  0.214021  0.006917

# %%
df3.plot(kind='bar')
# Out:
# <Axes: >

# %%
df3.plot.bar() #another way of using bar graph using plot.bar()
# Out:
# <Axes: >

# %%
df3.plot.barh() #Transpose
# Out:
# <Axes: >

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
gf1=df1.plot.hist()# x axis represents range and y axis represents values
gf1.set_xlabel("X-axis= range of values")
gf1.set_ylabel("Y axis= frequency")
# Out:
# Text(0, 0.5, 'Y axis= frequency')

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df1['sepal_length'].plot.hist(color='red')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot.hist(stacked=True,bins=100,figsize=(10,10),title='Histogram Of Iris')# stacked means it will show the overlapping and bins is the width of the graph
# Out:
# <Axes: title={'center': 'Histogram Of Iris'}, ylabel='Frequency'>

# %%
df1.plot.hist(stacked=True,bins=100,title='Histogram Of Iris',orientation='horizontal')
# Out:
# <Axes: title={'center': 'Histogram Of Iris'}, xlabel='Frequency'>

# %%
df1.hist() # separate graph for each index
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df1.hist(alpha=0.2)# alpha specifies the contrast of the graph
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df1.hist(color='#FF00FF')
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#to visualize the relationship between different columns , we use scater plot
df1.plot.scatter(x='sepal_width',y='petal_width')
# Out:
# <Axes: xlabel='sepal_width', ylabel='petal_width'>

# %%
df1.plot.scatter(x='sepal_length',y='petal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_width'>

# %%
df1.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df1.plot.scatter(x='sepal_length',y='petal_width',c='petal_length') #effect of sepal_length & petal_width on petal_length
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_width'>

# %%
df1.plot.scatter(x='sepal_length',y='sepal_width',label='Kumar',s=50)#s=size
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
df1.plot.scatter(x='sepal_length',y='sepal_width',label='Kumar',s=50,c='petal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
df1.plot.hexbin(x='sepal_length',y='sepal_width',label='Kumar',gridsize=10)# hexbin is used to display the data density.Used for large data sets
#the color of each hexagon tell about the no of points in that bin.
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
df
# Out:
#                 Data       data1     data2
# 2024-07-13  0.588131    0.588131  0.345898
# 2024-07-14  0.897714    1.485845  0.805890
# 2024-07-15  0.891531    2.377375  0.794827
# 2024-07-16  0.815837    3.193213  0.665591
# 2024-07-17  0.035890    3.229102  0.001288
# ...              ...         ...       ...
# 2027-04-04  0.992189  495.812936  0.984438
# 2027-04-05  0.756037  496.568973  0.571592
# 2027-04-06  0.299186  496.868159  0.089513
# 2027-04-07  0.261712  497.129872  0.068493
# 2027-04-08  0.968979  498.098851  0.938920
#
# [1000 rows x 3 columns]

# %%
df.iloc[0]
# Out:
# Data     0.588131
# data1    0.588131
# data2    0.345898
# Name: 2024-07-13 00:00:00, dtype: float64

# %%
df.iloc[0].plot.pie()  #shows the % of area
# Out:
# <Axes: ylabel='2024-07-13 00:00:00'>

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris3=df1.head(3).T
iris3
# Out:
#                    0       1       2
# sepal_length     5.1     4.9     4.7
# sepal_width      3.5     3.0     3.2
# petal_length     1.4     1.4     1.3
# petal_width      0.2     0.2     0.2
# species       setosa  setosa  setosa

# %%
iris3.iloc[0:4]
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
iris3.iloc[0:4].plot.pie(subplots=True,figsize=(20,20),autopct="%.2f",fontsize=13)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7760\1042840527.py:1: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# array([<Axes: ylabel='0'>, <Axes: ylabel='1'>, <Axes: ylabel='2'>],
#       dtype=object)

# %%
iris4=df1.head(3)

# %%
iris4
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
iris4.iloc[:,0:4]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2

# %%
iris4.iloc[:,0:4].plot.pie(subplots=True,figsize=(20,20),autopct="%.2f",fontsize=15) # without transpose, if we plot the piechart, then it will looks like this and will look odd.
# Out:
# array([<Axes: ylabel='sepal_length'>, <Axes: ylabel='sepal_width'>,
#        <Axes: ylabel='petal_length'>, <Axes: ylabel='petal_width'>],
#       dtype=object)

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
pd.plotting.scatter_matrix(df1,figsize=(10,10))# scatter plot showing the relationship of every column with everyone
#by default, the diagonal will be histogram, if we want a bell curve then see below cell
# Out:
# array([[<Axes: xlabel='sepal_length', ylabel='sepal_length'>,
#         <Axes: xlabel='sepal_width', ylabel='sepal_length'>,
#         <Axes: xlabel='petal_length', ylabel='sepal_length'>,
#         <Axes: xlabel='petal_width', ylabel='sepal_length'>],
#        [<Axes: xlabel='sepal_length', ylabel='sepal_width'>,
#         <Axes: xlabel='sepal_width', ylabel='sepal_width'>,
#         <Axes: xlabel='petal_length', ylabel='sepal_width'>,
#         <Axes: xlabel='petal_width', ylabel='sepal_width'>],
#        [<Axes: xlabel='sepal_length', ylabel='petal_length'>,
#         <Axes: xlabel='sepal_width', ylabel='petal_length'>,
#         <Axes: xlabel='petal_length', ylabel='petal_length'>,
#         <Axes: xlabel='petal_width', ylabel='petal_length'>],
#        [<Axes: xlabel='sepal_length', ylabel='petal_width'>,
#         <Axes: xlabel='sepal_width', ylabel='petal_width'>,
#         <Axes: xlabel='petal_length', ylabel='petal_width'>,
# ...

# %%
import scipy
pd.plotting.scatter_matrix(df1,figsize=(10,10),diagonal='kde')
# Out:
# array([[<Axes: xlabel='sepal_length', ylabel='sepal_length'>,
#         <Axes: xlabel='sepal_width', ylabel='sepal_length'>,
#         <Axes: xlabel='petal_length', ylabel='sepal_length'>,
#         <Axes: xlabel='petal_width', ylabel='sepal_length'>],
#        [<Axes: xlabel='sepal_length', ylabel='sepal_width'>,
#         <Axes: xlabel='sepal_width', ylabel='sepal_width'>,
#         <Axes: xlabel='petal_length', ylabel='sepal_width'>,
#         <Axes: xlabel='petal_width', ylabel='sepal_width'>],
#        [<Axes: xlabel='sepal_length', ylabel='petal_length'>,
#         <Axes: xlabel='sepal_width', ylabel='petal_length'>,
#         <Axes: xlabel='petal_length', ylabel='petal_length'>,
#         <Axes: xlabel='petal_width', ylabel='petal_length'>],
#        [<Axes: xlabel='sepal_length', ylabel='petal_width'>,
#         <Axes: xlabel='sepal_width', ylabel='petal_width'>,
#         <Axes: xlabel='petal_length', ylabel='petal_width'>,
# ...

# %%
df
# Out:
#                 Data       data1     data2
# 2024-07-13  0.588131    0.588131  0.345898
# 2024-07-14  0.897714    1.485845  0.805890
# 2024-07-15  0.891531    2.377375  0.794827
# 2024-07-16  0.815837    3.193213  0.665591
# 2024-07-17  0.035890    3.229102  0.001288
# ...              ...         ...       ...
# 2027-04-04  0.992189  495.812936  0.984438
# 2027-04-05  0.756037  496.568973  0.571592
# 2027-04-06  0.299186  496.868159  0.089513
# 2027-04-07  0.261712  497.129872  0.068493
# 2027-04-08  0.968979  498.098851  0.938920
#
# [1000 rows x 3 columns]

# %%
df['Data'].plot()
# Out:
# <Axes: >

# %%
df['Data'].plot(style='r--',legend=True,label='Kumar')#change the style
# Out:
# <Axes: >

# %%
df['Data'].plot(style='g-',legend=True,label='Kumar')#change the style
# Out:
# <Axes: >

# %%
df['Data'].plot(style='g*',legend=True,label='Kumar')#change the style
# Out:
# <Axes: >

# %%
# !pip install plotly
# !pip install cufflinks

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf

# %%
py.__version__
# Out:
# '5.22.0'

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot()#ploting using pandas
# Out:
# <Axes: >

# %%
df1.iplot() #visualization using plotly
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df1.iplot() #visualization using plotly
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\cufflinks\plotlytools.py:839, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     837 	if not isinstance(text,list):
#     838 		text=self[text].values
# ...

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
