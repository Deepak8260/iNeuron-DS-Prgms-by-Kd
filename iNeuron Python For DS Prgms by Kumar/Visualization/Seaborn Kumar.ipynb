# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='tip',y='total_bill',data=tips)

# %%
sns.relplot(x='tip',y='total_bill',data=tips,hue = 'smoker') #hue means color. Orange color are non smoker and blue are the smokers.

# %%
#sex wise graph
sns.relplot(x='tip',y='total_bill',data=tips,hue = 'sex')

# %%
#day wise graph
sns.relplot(x='tip',y='total_bill',data=tips,hue = 'day') # here we cant say that in thursday, who are the smoker and who are not

# %%
sns.relplot(x='tip',y='total_bill',data=tips,hue = 'day',style='smoker')# but here we can sapecify that in thursday, who are the smoker

# %%
sns.relplot(x='tip',y='total_bill',data=tips,hue = 'day',style='smoker',size='size')

# %%
sns.relplot(x='tip',y='total_bill',data=tips,size='size')

# %%
df=pd.DataFrame(np.random.randn(300,2),columns=['a','b'])
df
# Out:
#             a         b
# 0    0.881302 -0.307520
# 1   -1.354184 -0.736118
# 2    0.979967 -0.020028
# 3    0.582536  1.165815
# 4   -0.355868 -1.066500
# ..        ...       ...
# 295  0.313979  0.185047
# 296  0.311110 -0.073461
# 297  0.033183 -1.506640
# 298 -0.060195  1.037593
# 299  0.652885  0.548669
#
# [300 rows x 2 columns]

# %%
sns.relplot(x='a',y='b',kind='line',data=df,sort=True)

# %%
iris=sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x='sepal_length',y='sepal_width',data=iris)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x='day',y='tip',data=tips,hue='day')

# %%
sns.catplot(x='smoker',y='tip',data=tips,hue='smoker')

# %%
sns.catplot(x='day',y='tip',data=tips,kind='box',hue='sex')

# %%
x=np.random.randn(100000) # this alws generate a SND

# %%
x
# Out:
# array([ 1.22522333,  0.97295188, -0.9453415 , ..., -0.25730164,
#         0.39552476,  1.41183459])

# %%
sns.displot(x,kind='kde')

# %%
sns.distplot(x)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_11120\3746914587.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x)
# <Axes: ylabel='Density'>

# %%
sns.jointplot(x=tips['total_bill'],y=tips['tip'])#combination of two graphs

# %%
sns.jointplot(x=tips['total_bill'],y=tips['tip'],kind='hex')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris)#it will give scatter matrix

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)#scatter plot + best fitted line without linear regression

# %%
sns.regplot(x='total_bill',y='tip',data=tips) #same is lmplot
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='day')#daywise scatter plot

# %%
sns.boxplot(x='tip',data=tips)
# Out:
# <Axes: xlabel='tip'>

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Create a line plot
plt.plot(x, y, marker='o')
# Add titles and labels
plt.title("Sample Line Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Show the plot
plt.show()

# %%
sc=pd.DataFrame({'x' : [1, 2, 3, 4, 5],'y' : [2, 3, 5, 7, 11]})
sc
# Out:
#    x   y
# 0  1   2
# 1  2   3
# 2  3   5
# 3  4   7
# 4  5  11

# %%
sns.lineplot(x='x',y='y',data=sc,marker='o')
# Out:
# <Axes: xlabel='x', ylabel='y'>
